# %%
# !git clone https://github.com/dikey4405/23520728_Lab2_DeepLearning.git
# !ls
# Out:
# Cloning into 'Lab2_DeepLearning'...
# remote: Enumerating objects: 101, done.
# remote: Counting objects: 100% (101/101), done.
# remote: Compressing objects: 100% (97/97), done.
# remote: Total 101 (delta 51), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (101/101), 21.59 MiB | 12.41 MiB/s, done.
# Resolving deltas: 100% (51/51), done.
# assignments.ipynb  Bai3.py     Lab2_DeepLearning  __pycache__
# Bai1.py		   Bai4.py     mnist_dataset.py   README.md
# Bai2.py		   checkpoint  model		  VinaFood_dataset.py

# %%
# %cd 23520728_Lab2_DeepLearning
# Out:
# /kaggle/working/Lab2_DeepLearning/Lab2_DeepLearning/Lab2_DeepLearning/Lab2_DeepLearning/Lab2_DeepLearning/Lab2_DeepLearning/Lab2_DeepLearning/Lab2_DeepLearning/Lab2_DeepLearning/Lab2_DeepLearning

# %%
# !pip install idx2numpy
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for idx2numpy: filename=idx2numpy-1.2.3-py3-none-any.whl size=7903 sha256=81a95a1b5c0951cc1b59573ff9f56caae2797f810556925b99a57950c1a9700a
#   Stored in directory: /root/.cache/pip/wheels/87/e5/e7/70fc742b3645ddf9d392f766feccbcc95cb3a3c806f8588af0
# Successfully built idx2numpy
# ...

# %%
# !python Bai1.py
# Out:
# Epoch 1/10
# 	- loss: 0.8756894982933998
# 	-precision: 0.9237123254081437
# 	-recall: 0.923856522617759
# 	-f1: 0.9235501457319023
# Epoch 2/10
# 	- loss: 0.21055770953645309
# 	-precision: 0.9550742457922808
# 	-recall: 0.9555007212416691
# 	-f1: 0.9551377874530098
# Epoch 3/10
# 	- loss: 0.13560140232791504
# 	-precision: 0.9686654860324436
# 	-recall: 0.9680369293945471
# 	-f1: 0.9681078646654852
# Epoch 4/10
# 	- loss: 0.09997512550403674
# 	-precision: 0.9714698490008379
# 	-recall: 0.9708783881963543
# 	-f1: 0.9709999381578653
# Epoch 5/10
# 	- loss: 0.08260534723127881
# 	-precision: 0.9761647574413832
# 	-recall: 0.9761303695839425
# 	-f1: 0.9760147281688681
# Epoch 6/10
# 	- loss: 0.06881433032676577
# 	-precision: 0.9759581888951017
# 	-recall: 0.9752507121964387
# 	-f1: 0.9753305827085935
# Epoch 7/10
# 	- loss: 0.05983438343902429
# 	-precision: 0.9787315795772823
# 	-recall: 0.978006370039078
# 	-f1: 0.978214679283635
# Epoch 8/10
# 	- loss: 0.05440479136323556
# ...

# %%
# !python Bai2.py
# Out:
# Epoch 1/10
# 	- loss: 15.131535429863414
# 	-precision: 0.0043257650261541315
# 	-recall: 0.047619047619047616
# 	-f1: 0.00793106376862722
# Epoch 2/10
# 	- loss: 2.9793715564308654
# 	-precision: 0.0043257650261541315
# 	-recall: 0.047619047619047616
# 	-f1: 0.00793106376862722
# Epoch 3/10
# 	- loss: 2.978447942217444
# 	-precision: 0.0043257650261541315
# 	-recall: 0.047619047619047616
# 	-f1: 0.00793106376862722
# Epoch 4/10
# 	- loss: 2.9784152583711467
# 	-precision: 0.0043257650261541315
# 	-recall: 0.047619047619047616
# 	-f1: 0.00793106376862722
# Epoch 5/10
# 	- loss: 2.9784023431456013
# 	-precision: 0.0043257650261541315
# 	-recall: 0.047619047619047616
# 	-f1: 0.00793106376862722
# Epoch 6/10
# 	- loss: 2.978279184004304
# 	-precision: 0.003990821111443679
# 	-recall: 0.047619047619047616
# 	-f1: 0.007364448126668507
# Epoch 7/10
# 	- loss: 2.9784811010026626
# 	-precision: 0.003990821111443679
# 	-recall: 0.047619047619047616
# 	-f1: 0.007364448126668507
# Epoch 8/10
# ...

# %%
# !python Bai3.py
# Out:
# Epoch 1/10
# 	- loss: 2.719692903908954
# 	-precision: 0.16698162250584117
# 	-recall: 0.20472058458384035
# 	-f1: 0.16410735865364842
# Epoch 2/10
# 	- loss: 2.3983468354507615
# 	-precision: 0.2668466252858942
# 	-recall: 0.22922719403708702
# 	-f1: 0.1978043421567744
# Epoch 3/10
# 	- loss: 2.2639437967045293
# 	-precision: 0.24224274501518409
# 	-recall: 0.24822036975489714
# 	-f1: 0.21825923397057453
# Epoch 4/10
# 	- loss: 2.113299486553593
# 	-precision: 0.2850473427163772
# 	-recall: 0.2612367074279466
# 	-f1: 0.23630752015926126
# Epoch 5/10
# 	- loss: 2.0075127503294854
# 	-precision: 0.3533028344167016
# 	-recall: 0.31204708223061833
# 	-f1: 0.27919249803286045
# Epoch 6/10
# 	- loss: 1.8840061298980835
# 	-precision: 0.32178750709989545
# 	-recall: 0.2341983111252263
# 	-f1: 0.21273978527315376
# Epoch 7/10
# 	- loss: 1.780173387497094
# 	-precision: 0.39795985613854656
# 	-recall: 0.34244471712627716
# 	-f1: 0.30727299067893565
# Epoch 8/10
# 	- loss: 1.6441336491495182
# ...

# %%
# !python Bai4.py
# Out:
# 2025-10-29 16:44:01.247414: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761756241.269786     231 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761756241.277644     231 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Using device: cuda
# config.json: 69.6kB [00:00, 55.2MB/s]
# model.safetensors: 100%|█████████████████████| 102M/102M [00:01<00:00, 97.6MB/s]
# Epoch 1/10
# 	- loss: 1.789413
# 	-precision: 0.715710
# 	-recall: 0.694780
# 	-f1: 0.691065
# New best model saved: checkpoint/bai4/best_epoch_1_f1_0.6911.pth
# Epoch 2/10
# 	- loss: 0.780879
# ...
